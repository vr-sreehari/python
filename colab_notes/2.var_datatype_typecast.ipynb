# %% [markdown]
# # Variable

# %% [markdown]
# * A-Z, a-z allowed
# * Underscore allowed
# * Numbers allowd but not at the first position(char)
# * Keywords not allowed
# * Give meaningful variable name
# * It's Case Sensitive

# %%
NAME = "Agalya"

# %%
name = "Prakash"

# %%
Name = "Durga"

# %%
nAme = "Thiru"

# %%
User_name = "Niroshini"

# %%
Name1 = "Sreehari"
Name2 = "Prasanna"

# %%
1Name = "selva"
# Out:
#   File "/tmp/ipykernel_3693/3228021280.py", line 1
#     1Name = "selva"
#     ^
# SyntaxError: invalid decimal literal

# %%
_name = "Selva"

# %%
user_name1 = input("Enter your name: ")
city = input("Enter your City: ")


print(user_name1)
print(city)
# Out:
# Enter your name: Selva
# Enter your City: Chennai
# Selva
# Chennai

# %%
print(user_name1,city)
# Out:
# Selva Chennai

# %%
print("User name is: ",user_name1,", he is located in ",city)
# Out:
# User name is:  Selva , he is located in  Chennai

# %%
print(_name)
# Out:
# Selva

# %%
_name = "Jaih"

# %%
print(_name)
# Out:
# Jaih

# %% [markdown]
# # Data Types

# %% [markdown]
# ## Integer

# %%
age = 10
type(age)
# Out:
# int

# %% [markdown]
# ## Float

# %%
height = 5.5
type(height)
# Out:
# float

# %% [markdown]
# ### String

# %%
name1 = "Abirami"

# %%
name2 = 'jaihdiksha'

# %%
type(name1)
# Out:
# str

# %%
type(name2)
# Out:
# str

# %%
dummy = "12234567890qrtyuiop;[];.,mnbvvcx"
type(dummy)
# Out:
# str

# %%
dummy = "1223"
type(dummy)
# Out:
# str

# %%
dummy = input()
type(dummy)
# Out:
# 10
# str

# %%
dummy
# Out:
# '10'

# %% [markdown]
# ## Boolean

# %%
b_value1 = True
b_value2 = False
type(b_value1)
# Out:
# bool

# %%
type(b_value2)
# Out:
# bool

# %% [markdown]
# # Type Conversion or type casting

# %%
weight = "60.45"
type(weight)
# Out:
# str

# %%
new_weight = float(weight)
type(new_weight)
# Out:
# float

# %%
weight
# Out:
# '60.45'

# %%
new_weight
# Out:
# 60.45

# %%
int_weight = int(new_weight)
type(int_weight)
# Out:
# int

# %%
int_weight
# Out:
# 60

# %%
float_weight = float(int_weight)
type(float_weight)
# Out:
# float

# %%
float_weight
# Out:
# 60.0

# %%
str_weight = str(float_weight)
type(str_weight)
# Out:
# str

# %%
str_weight
# Out:
# '60.0'

# %%
name = input("Enter your name: ")
Emp_id = int(input("Enter your Employee ID: "))
salary = float(input("Enter your salary: "))

print("Employee name is: ",name)
print("Employee ID is: ",Emp_id)
print("Employee salary is: ",salary)
# Out:
# Enter your name: Divya Bharathi
# Enter your Employee ID: 45687
# Enter your salary: 59650.54
# Employee name is:  Divya Bharathi
# Employee ID is:  45687
# Employee salary is:  59650.54

# %%
type(name)
# Out:
# str

# %%
type(Emp_id)
# Out:
# int

# %%
type(salary)
# Out:
# float

# %%
type(Salary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3693/711086876.py in <cell line: 0>()
# ----> 1 type(Salary)
#
# NameError: name 'Salary' is not defined

# %%
Emp_id = int(input("Enter your Employee ID: "))
# Out:
# Enter your Employee ID: a12345
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3693/4171693668.py in <cell line: 0>()
# ----> 1 Emp_id = int(input("Enter your Employee ID: "))
#
# ValueError: invalid literal for int() with base 10: 'a12345'

# %%
Emp_id = input("Enter your Employee ID: ")
# Out:
# Enter your Employee ID: a12345

# %%
Emp_id
# Out:
# 'a12345'

# %%
Emp_id = input("Enter your Employee ID: ")
# Out:
# Enter your Employee ID: 10

# %%
type(Emp_id)
# Out:
# str

# %% [markdown]
# Tomorrow topic

# %% [markdown]
# * String methods
# * data structures

# %%
String
