# %% [markdown]
# # Output

# %%
print("Hello World")
# Out:
# Hello World

# %%
print('Welcome to Guvi Course')
# Out:
# Welcome to Guvi Course

# %% [markdown]
# # Input

# %%
input()
# Out:
# ghsfjhsfdhfjsj
# 'ghsfjhsfdhfjsj'

# %%
input("Enter your name: ")
# Out:
# Enter your name: Selva
# 'Selva'

# %%
input("Enter your mobile number: ")
# Out:
# Enter your mobile number: 987654321015541
# '987654321015541'

# %% [markdown]
# # Variable

# %%
name = input("Enter your name: ")
# Out:
# Enter your name: Selva

# %%
name
# Out:
# 'Selva'
