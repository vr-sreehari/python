# %% [markdown]
# # String

# %% [markdown]
# ## Indexing and Slicing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
name = "THIRUMURUGAN"

# %%
name[0]
# Out:
# 'T'

# %%
name[-12]
# Out:
# 'T'

# %%
name[11]
# Out:
# 'N'

# %%
name[-1]
# Out:
# 'N'

# %%
name[0:5]
# Out:
# 'THIRU'

# %%
name[7:11]
# Out:
# 'RUGA'

# %%
name[-5:-2]
# Out:
# 'RUG'

# %%
name[-5:-1]
# Out:
# 'RUGA'

# %%
name[7:12]
# Out:
# 'RUGAN'

# %%
name[:5]
# Out:
# 'THIRU'

# %%
name[7:]
# Out:
# 'RUGAN'

# %%
name[:-7]
# Out:
# 'THIRU'

# %%
name[1:4]
# Out:
# 'HIR'

# %%
name[7:10]
# Out:
# 'RUG'

# %%
name[1:4]+name[7:10]
# Out:
# 'HIRRUG'

# %%
name2="Merolin Ashick J s"

# %%
name2[4:9]
# Out:
# 'lin A'

# %%
name2[-14:-9]
# Out:
# 'lin A'

# %%
name2
# Out:
# 'Merolin Ashick J s'

# %%
dummy = "123456789"
type(dummy)
# Out:
# str

# %%
name2="Merolin Ashick J s"

# %%
name2[::-1]
# Out:
# 's J kcihsA niloreM'

# %%
name2[::0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2206/3956139369.py in <cell line: 0>()
# ----> 1 name2[::0]
#
# ValueError: slice step cannot be zero

# %%
name2[::1]
# Out:
# 'Merolin Ashick J s'

# %%
name2[::2]
# Out:
# 'MrlnAhc  '

# %%
name2[::-2]
# Out:
# 'sJkis ioe'

# %%
name[::-2]
# Out:
# 'NGRMRH'

# %%
name[::]
# Out:
# 'THIRUMURUGAN'

# %%
name[::2]
# Out:
# 'TIUUUA'

# %%
name[::-1]
# Out:
# 'NAGURUMURIHT'

# %%
name3 = "DHAMAYANTHI"

# %%
name3[::2]
# Out:
# 'DAAATI'

# %%
name3[::-2]
# Out:
# 'ITAAAD'

# %%
name3[::2]

# %%
name4 = "DIVYA BHARATHI"

# %%
name4[1:8:2]
# Out:
# 'IY H'

# %%
name4[-13:-6:2]
# Out:
# 'IY H'

# %%
name4[-7:-12:-1]
# Out:
# 'HB AY'

# %%
name4[-7:-14:-1]
# Out:
# 'HB AYVI'

# %%
name5 = "abirami"

# %%
name5[3:6:1]
# Out:
# 'ram'

# %%
name5[-2:-5:-1]
# Out:
# 'mar'

# %%
name5[-2:-7:-2]
# Out:
# 'mrb'

# %% [markdown]
# # Manipulation using default methods

# %% [markdown]
# * split
# * count
# * find
# * replace
# * index
# * upper
# * lower
# * capitilize
# * title

# %%
name5 = "Abirami Sivasankaran"

# %%
name5.split()
# Out:
# ['Abirami', 'Sivasankaran']

# %%
a = "Why Python for Data Science?"
a.split()
# Out:
# ['Why', 'Python', 'for', 'Data', 'Science?']

# %%
name5 = "Abirami_Siva_sankaran"
name5.split()
# Out:
# ['Abirami_Siva_sankaran']

# %%
name5 = "Abirami_Siva_sankaran"
name5.split("_")
# Out:
# ['Abirami', 'Siva', 'sankaran']

# %%
name5 = "Abirami_Siva_sankaran"
name5.split("a")
# Out:
# ['Abir', 'mi_Siv', '_s', 'nk', 'r', 'n']

# %%
name5.count("a")
# Out:
# 5

# %%
name5.count("z")
# Out:
# 0

# %%
name5.index("a")
# Out:
# 4

# %%
name5.index("z")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2206/3656085859.py in <cell line: 0>()
# ----> 1 name5.index("z")
#
# ValueError: substring not found

# %%
name5.find("a")
# Out:
# 4

# %%
name5.find("z")
# Out:
# -1

# %%
name5.find("A")
# Out:
# 0

# %%
name5.replace("a","A")
# Out:
# 'AbirAmi_SivA_sAnkArAn'

# %%
name5.count("Siva")
# Out:
# 1

# %%
name5
# Out:
# 'Abirami_Siva_sankaran'

# %%
name5.index("Siva")
# Out:
# 8

# %%
name5.replace("Siva","SIVA")
# Out:
# 'Abirami_SIVA_sankaran'

# %%
name5
# Out:
# 'Abirami_Siva_sankaran'

# %%
name5 = name5.replace("Siva","SIVA")

# %%
name5
# Out:
# 'Abirami_SIVA_sankaran'

# %%
name5
# Out:
# 'Abirami_SIVA_sankaran'

# %%
name5 = name5.replace("I","1")

# %%
name5
# Out:
# 'Abirami_S1VA_sankaran'

# %%
name5 = name5.lower()
name5
# Out:
# 'abirami_s1va_sankaran'

# %%
name5 = name5.upper()
name5
# Out:
# 'ABIRAMI_S1VA_SANKARAN'

# %%
name5 = name5.title()
name5
# Out:
# 'Abirami_S1Va_Sankaran'

# %%
name5 = name5.capitalize()
name5
# Out:
# 'Abirami_s1va_sankaran'

# %%
age = "55"

# %%
age.isalnum()
# Out:
# True

# %%
age.isalpha()
# Out:
# False

# %%
age.isnumeric()
# Out:
# True

# %%
check = age.isnumeric()

# %%
type(check)
# Out:
# bool

# %% [markdown]
# # Operators

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
num1 = 10
num2 = 20
total = num1+num2
total
# Out:
# 30

# %%
num1 = 10
num2 = 20
minus = num1-num2
minus
# Out:
# -10

# %%
num1 = 10
num2 = 20
multi = num1*num2
multi
# Out:
# 200

# %%
num1 = 100
num2 = 3
div = num1/num2
div
# Out:
# 33.333333333333336

# %%
floor_div = num1//num2
floor_div
# Out:
# 33

# %%
print(floor_div) #I am performing floor division
# Out:
# 33

# %%
"""
I am performing
arthimethmatic opertors
"""
reminder = num1%num2
reminder
# Out:
# 1

# %%
#3**5
num1 = 3
num2 = 5
power_cal = num1**num2
power_cal
# Out:
# 243
