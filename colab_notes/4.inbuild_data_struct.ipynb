# %% [markdown]
# # String Manipulation

# %%
name = "    Selva   "
name.strip()
# Out:
# 'Selva'

# %%
name = "    Selva Mani   "
name.strip()
# Out:
# 'Selva Mani'

# %% [markdown]
# # Operators

# %% [markdown]
# Assignment
# Comparison
# Logical
# Membership
# Indentity
# Bitwise

# %% [markdown]
# ## Assignment =, +=, -=, *=, /=, //=, %=, **=,

# %%
a = 10

# %%
a = a + 10
a
# Out:
# 20

# %%
num1 = 10
num1 += 10
num1
# Out:
# 20

# %%
num2 = 30
num2 -= 5
num2
# Out:
# 25

# %%
num3 = 40
num3 *= 2
num3
# Out:
# 80

# %%
num4 = 20
num4 /= 5
num4
# Out:
# 4.0

# %%
num5 = 60
num5 //= 3
num5
# Out:
# 20

# %%
num6 = 70
num6 %= 3
num6
# Out:
# 1

# %%
num7 = 100
num7 **= 2
num7
# Out:
# 10000

# %% [markdown]
# ## Comparison operators ==, !=, <, >, <=, >=

# %%
num1 = input("Enter first numer")
num2 = input("Enter Second numer")
num1 == num2
# Out:
# Enter first numer 50
# Enter Second numer 49
# False

# %%
num1 = input("Enter first numer")
num2 = input("Enter Second numer")
num1 != num2
# Out:
# Enter first numer 25
# Enter Second numer 30
# True

# %%
num1 = input("Enter first numer")
num2 = input("Enter Second numer")
num1 < num2
# Out:
# Enter first numer 50
# Enter Second numer 30
# False

# %%
num1 = input("Enter first numer")
num2 = input("Enter Second numer")
num1 > num2
# Out:
# Enter first numer 50
# Enter Second numer 30
# True

# %%
num1 = input("Enter first numer")
num2 = input("Enter Second numer")
num1 <= num2
# Out:
# Enter first numer 50
# Enter Second numer 50
# True

# %%
num1 = input("Enter first numer")
num2 = input("Enter Second numer")
num1 >= num2
# Out:
# Enter first numer 50
# Enter Second numer 50
# True

# %% [markdown]
# ## Logical Operators (and, or, not)

# %%
num1 = input("Enter first number")
num2 = input("Enter Second number")
num3 = input("Enter Third number")
num1 == num2 and num1 == num3
# Out:
# Enter first number 50
# Enter Second number 50
# Enter Third number 50
# True

# %%
num1 = input("Enter first number")
num2 = input("Enter Second number")
num3 = input("Enter Third number")
num1 == num2 or num1 == num3
# Out:
# Enter first number 49
# Enter Second number 50
# Enter Third number 51
# False

# %%
num1 = input("Enter first number")
num2 = input("Enter Second number")
num3 = input("Enter Third number")
num1 == num2 or num1 == num3
# Out:
# Enter first number 50
# Enter Second number 49
# Enter Third number 50
# True

# %%
num1 = input("Enter first number")
num2 = input("Enter Second number")
num3 = input("Enter Third number")
num1 == num2 or num1 == num3
# Out:
# Enter first number 50
# Enter Second number 50
# Enter Third number 50
# True

# %%
num1 = input("Enter first number")
num2 = input("Enter Second number")
num3 = input("Enter Third number")
not(num1 == num2)
# Out:
# Enter first number 50
# Enter Second number 50
# Enter Third number 50
# False

# %% [markdown]
# ## Membership Operators (in, not in)

# %%
names = ["Selva","Mani","Thiru","Saravanan","Abirami","Dhamayanthi","Merolin"]

# %%
check_name = input("Enter a name")
check_name in names
# Out:
# Enter a name Thiru
# True

# %%
check_name = input("Enter a name")
check_name in names
# Out:
# Enter a name thiru
# False

# %%
check_name = input("Enter a name")
check_name in names
# Out:
# Enter a name dhivya
# False

# %%
check_name = input("Enter a name")
check_name not in names
# Out:
# Enter a name Thiru
# False

# %% [markdown]
# ## Indentity Operators (is, is not)

# %%
a = 1000
b = 1000
a == b
# Out:
# True

# %%
a = 1000
b = 1000
a is b
# Out:
# False

# %%
num1 = 1000
num2 = num1
num2
# Out:
# 1000

# %%
num1 is num2
# Out:
# True

# %%
num1 is not num2
# Out:
# False

# %%
6 & 7
# Out:
# 6

# %%
7 | 6
# Out:
# 7

# %%
5 & 10
# Out:
# 0

# %%
5 | 10
# Out:
# 15

# %% [markdown]
# # Python Inbuilt Data Structures

# %% [markdown]
# ## List
#
# * [ ]
# * Mutable
# * ordered
# * Indexing

# %%
list_var = [10, 10.5, "python", "programming", True, False]

# %%
type(list_var)
# Out:
# list

# %%
list_var[0]
# Out:
# 10

# %%
list_var[3]
# Out:
# 'programming'

# %%
list_var[2] = "Python"

# %%
list_var
# Out:
# [10, 10.5, 'Python', 'programming', True, False]

# %%
list_var.append("HCL GUVI")

# %%
list_var
# Out:
# [10, 10.5, 'Python', 'programming', True, False, 'HCL GUVI']

# %%
list_var.extend(["Data Science","SQL",3])

# %%
list_var
# Out:
# [10,
#  10.5,
#  'Python',
#  'programming',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science',
#  'SQL',
#  3]

# %%
list_var.insert(4,"Day 4")

# %%
list_var
# Out:
# [10,
#  10.5,
#  'Python',
#  'programming',
#  'Day 4',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science',
#  'SQL',
#  3]

# %%
list_var1 = list_var

# %%
list_var1
# Out:
# [10,
#  10.5,
#  'Python',
#  'programming',
#  'Day 4',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science',
#  'SQL',
#  3]

# %%
list_var1[3] = "Programming"

# %%
list_var1
# Out:
# [10,
#  10.5,
#  'Python',
#  'Programming',
#  'Day 4',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science',
#  'SQL',
#  3]

# %%
list_var
# Out:
# [10,
#  10.5,
#  'Python',
#  'Programming',
#  'Day 4',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science',
#  'SQL',
#  3]

# %%
list_var2 = list_var.copy()

# %%
list_var2
# Out:
# [10,
#  10.5,
#  'Python',
#  'Programming',
#  'Day 4',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science',
#  'SQL',
#  3]

# %%
list_var2[3] = "programming"
list_var2
# Out:
# [10,
#  10.5,
#  'Python',
#  'programming',
#  'Day 4',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science',
#  'SQL',
#  3]

# %%
list_var
# Out:
# [10,
#  10.5,
#  'Python',
#  'Programming',
#  'Day 4',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science',
#  'SQL',
#  3]

# %%
list_var2.count(10)
# Out:
# 1

# %%
list_var.append(10)

# %%
list_var.append(10)

# %%
list_var
# Out:
# [10,
#  10.5,
#  'Python',
#  'Programming',
#  'Day 4',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science',
#  'SQL',
#  3,
#  10,
#  10]

# %%
list_var.count(10)
# Out:
# 3

# %%
list_var
# Out:
# [10,
#  10.5,
#  'Python',
#  'Programming',
#  'Day 4',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science',
#  'SQL',
#  3,
#  10,
#  10]

# %%
list_var.pop()
# Out:
# 10

# %%
list_var.pop()
# Out:
# 10

# %%
list_var.pop()
# Out:
# 3

# %%
list_var
# Out:
# [10,
#  10.5,
#  'Python',
#  'Programming',
#  'Day 4',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science',
#  'SQL']

# %%
list_var.pop()
# Out:
# 'SQL'

# %%
list_var
# Out:
# [10,
#  10.5,
#  'Python',
#  'Programming',
#  'Day 4',
#  True,
#  False,
#  'HCL GUVI',
#  'Data Science']

# %%
list_var = [10, 10.5, "python", "programming", True, False]

# %%
list_var.pop()
# Out:
# False

# %%
list_var.pop(1)
# Out:
# 10.5

# %%
list_var.remove('Programming')

# %%
list_var
# Out:
# [10, 10.5, 'Python', 'Day 4', True, False, 'HCL GUVI', 'Data Science']

# %%
list_var.append(10)

# %%
list_var
# Out:
# [10, 10.5, 'Python', 'Day 4', True, False, 'HCL GUVI', 'Data Science', 10]

# %%
list_var.remove(10)
list_var
# Out:
# [10.5, 'Python', 'Day 4', True, False, 'HCL GUVI', 'Data Science', 10]

# %%
list_var.remove(10)
list_var
# Out:
# [10.5, 'Python', 'Day 4', True, False, 'HCL GUVI', 'Data Science']

# %%
new_list = [10,20,30,40]

# %%
max(new_list)
# Out:
# 40

# %%
min(new_list)
# Out:
# 10

# %%
sum(new_list)
# Out:
# 100

# %%
len(new_list)
# Out:
# 4

# %%
list_var.remove(10.5)

# %%
list_var
# Out:
# ['Python', 'Day 4', True, False, 'HCL GUVI', 'Data Science']

# %%
list1 = [10,20,30, ["Name","Age","Gender"],40,50,60]

# %%
list1
# Out:
# [10, 20, 30, ['Name', 'Age', 'Gender'], 40, 50, 60]

# %%
list1.append(["Data Science","SQL",3])
list1
# Out:
# [10, 20, 30, ['Name', 'Age', 'Gender'], 40, 50, 60, ['Data Science', 'SQL', 3]]

# %%
list1.extend(["Data Science","SQL",3])
list1
# Out:
# [10,
#  20,
#  30,
#  ['Name', 'Age', 'Gender'],
#  40,
#  50,
#  60,
#  ['Data Science', 'SQL', 3],
#  'Data Science',
#  'SQL',
#  3]

# %% [markdown]
# ## Tuple
#
# * ( )
# * Immutable
# * Indexing

# %%
tup_var1 = (10,20,30, "Day 4", "Operators","Data Types","Data Collection")

# %%
type(tup_var)
# Out:
# tuple

# %%
tup_var2 = (10,20,30, "Day 4", "Operators","Data Types","Data Collection",(10,20,30,40))

# %%
tup_var2
# Out:
# (10,
#  20,
#  30,
#  'Day 4',
#  'Operators',
#  'Data Types',
#  'Data Collection',
#  (10, 20, 30, 40))

# %%
tup_var2 = (10,20,30, "Day 4", "Operators","Data Types","Data Collection",[10,20,30,40])

# %%
tup_var2
# Out:
# (10,
#  20,
#  30,
#  'Day 4',
#  'Operators',
#  'Data Types',
#  'Data Collection',
#  [10, 20, 30, 40])

# %%
tup_var2.count(10)
# Out:
# 1

# %%
tup_var2[7].count(10)
# Out:
# 1

# %%
tup_var2[7]
# Out:
# [10, 20, 30, 40]

# %%
tup_var2[7].index(20)
# Out:
# 1

# %%
tup_var2.index("Data Types")
# Out:
# 5

# %%
tup_var2 = (20,30, 10, "Day 4", "Operators","Data Types","Data Collection",[10])

# %%
tup_var2.count(10)
# Out:
# 1

# %%
tup_var2.count([10])
# Out:
# 1

# %%
tup_var2.index(10)
# Out:
# 2

# %%
tup_var2.index([10])
# Out:
# 7

# %%
type(tup_var2)
# Out:
# tuple

# %%
tup_var2 = 10

# %%
type(tup_var2)
# Out:
# int

# %% [markdown]
# ## Set
#
# * { }
# * Mutable
# * unorder
# * non-indexed
# * Non - Duplicate

# %%
set_var = {50,20,10,"Selva","Vinoth","Shiva","Arun",10}
set_var
# Out:
# {10, 20, 50, 'Arun', 'Selva', 'Shiva', 'Vinoth'}

# %% [markdown]
# add, remove, pop, union, intersection

# %%
set_var.add("Joe")

# %%
set_var
# Out:
# {10, 20, 50, 'Arun', 'Joe', 'Selva', 'Shiva', 'Vinoth'}

# %%
set_var.pop()
# Out:
# 50

# %%
set_var.pop()
# Out:
# 'Joe'

# %%
set_var
# Out:
# {10, 20, 'Arun', 'Selva', 'Shiva', 'Vinoth'}

# %%
set_var.remove("Arun")

# %%
set_var
# Out:
# {10, 20, 'Selva', 'Shiva', 'Vinoth'}

# %%
set_var.add(10)

# %%
set_var
# Out:
# {10, 20, 'Selva', 'Shiva', 'Vinoth'}

# %%
set_var1 = {10,20,30,40,50}
set_var2 = {30,40,50,60,70}

set_var1.union(set_var2)
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
set_var1.intersection(set_var2)
# Out:
# {30, 40, 50}
